# %%
from pyspark.mllib.recommendation import ALS
import shlex
import itertools

CLIMB_FIELDS = ['id', 'name', 'rating', 'type', 'location', 'url',
                'location_url']
PARENT_DIR = "/home/anant/projects/climb_recommender/{}"
MY_RATINGS = PARENT_DIR.format("my_ratings.csv")
REVIEWS = PARENT_DIR.format("reviews.csv")
CLIMBS = PARENT_DIR.format("climbs.csv")

def parse_my_ratings(line):
    """                                                                                                                                                                                                                                                                    
    climb_id, user_id, rating                                                                                                                                                                                                                                              
    """
    vals = line.split(",")
    return (int(vals[1]), int(vals[0]), int(vals[2]))

def parse_ratings(line):
    vals = line.split(",")
    return (int(vals[0]), (int(vals[2]), int(vals[1]), int(vals[3])))

def parse_climb(line):
    vals = line.split(",")
    climbs_dict = dict(zip(CLIMB_FIELDS[1:], vals[1:]))
    climbs_dict['id'] = line.split(",")[0]
    return climbs_dict

# %%
my_ratings = sc.textFile(MY_RATINGS).map(parse_my_ratings)
ratings = sc.textFile(REVIEWS).map(parse_ratings)
climbs = sc.textFile(CLIMBS).map(parse_climb)
max_ratings = ratings.count()
my_ratings.take(5)
climbs_dict = {int(climb['id']): climb for climb in climbs.collect()}

# %%
def computeRmse(model, data, n):
    """
    Compute RMSE (Root Mean Squared Error).
    """
    ds = data.map(lambda x: (x[0], x[1]))
    predictions = model.predictAll(ds)
    predictionsAndRatings = predictions.map(lambda x: ((x[0], x[1]), x[2])) \
      .join(data.map(lambda x: ((x[0], x[1]), x[2]))) \
      .values()
    return sqrt(predictionsAndRatings.map(lambda x: (x[0] - x[1]) ** 2).reduce(add) / float(n))

# %%
numPartitions = 6

# %%
training = ratings.values().union(my_ratings).repartition(numPartitions).cache()

# %%
validation = ratings.filter(lambda x: x[0] >= 6 and x[0] < 8).values().repartition(numPartitions).cache()
print "VALIDATION: {}".format(validation.take(5))
test = ratings.filter(lambda x: x[0] >  8).values().repartition(numPartitions).cache()
print "TEST: {}".format(test.take(5))
numValidation = validation.count()
# Out:
# VALIDATION: [(107884765, 106465048, 3), (109479454, 106465048, 99), (109124423, 106465048, 99), (106633259, 106465048, 99), (106500571, 106465048, 99)]
# TEST: [(106828672, 106465048, 3), (108467624, 106465048, 99), (106093974, 106465048, 99), (106843841, 106776405, 3), (106534563, 106776405, 2)]

# %%
ranks = [8, 12]
lambdas = [0.1, 10.0]
numIters = [10, 20]

bestModel = None
bestValidationRmse = float("inf")
bestRank = 0
bestLambda = -1.0
bestNumIter = -1

for rank, lmbda, numIter in itertools.product(ranks, lambdas, numIters):
   model = ALS.train(training, rank, numIter, lmbda)
   validationRmse = computeRmse(model, validation, numValidation)
   print ("RMSE (validation) = {} for the model trained with ".format(validationRmse),
       "rank = {}, lambda = {}, and numIter = {}.".format(rank, lmbda, numIter))
   if (validationRmse < bestValidationRmse):
       bestModel = model
       bestValidationRmse = validationRmse
       bestRank = rank
       bestLambda = lmbda
       bestNumIter = numIter
# Out:
# ('RMSE (validation) = 41.9532500586 for the model trained with ', 'rank = 8, lambda = 0.1, and numIter = 10.')
# ('RMSE (validation) = 41.8685572059 for the model trained with ', 'rank = 8, lambda = 0.1, and numIter = 20.')
# ('RMSE (validation) = 45.1297036406 for the model trained with ', 'rank = 8, lambda = 10.0, and numIter = 10.')
# ('RMSE (validation) = 45.1499995574 for the model trained with ', 'rank = 8, lambda = 10.0, and numIter = 20.')
# ('RMSE (validation) = 41.5726958265 for the model trained with ', 'rank = 12, lambda = 0.1, and numIter = 10.')
# ('RMSE (validation) = 41.4320297517 for the model trained with ', 'rank = 12, lambda = 0.1, and numIter = 20.')
# ('RMSE (validation) = 45.1260898987 for the model trained with ', 'rank = 12, lambda = 10.0, and numIter = 10.')
# ('RMSE (validation) = 45.1516355291 for the model trained with ', 'rank = 12, lambda = 10.0, and numIter = 20.')

# %%
my_rated = [rating[2] for rating in my_ratings.collect()]
candidate_climbs = sc.parallelize([climb for climb in climbs_dict.keys()])
candidate_climbs.collect()
# Out:
# [106496005,
#  106496009,
#  106201099,
#  106397713,
#  107741208,
#  108101666,
#  108724271,
#  108396596,
#  106496054,
#  106496065,
#  105928033,
#  106037323,
#  106496085,
#  106987613,
#  107391675,
#  106332262,
#  106332266,
#  106528897,
#  105971842,
#  105873545,
#  108003471,
#  108429456,
#  105873569,
#  108003490,
#  106725551,
#  108265663,
#  106179275,
#  106954960,
#  108265685,
#  105873622,
#  108265688,
#  105873628,
#  105939171,
#  106762721,
#  108265719,
#  106037501,
#  109543683,
#  106430726,
#  106037518,
#  107807001,
#  106496047,
#  106987805,
#  105840931,
#  106955044,
#  106955054,
#  108855604,
#  108069173,
#  106987832,
#  106561851,
#  107839808,
#  106814007,
#  106791245,
#  107020626,
#  106791251,
#  106791256,
#  106266970,
#  108855644,
#  106856800,
#  106791270,
#  106594666,
#  108265837,
#  106004871,
#  108724617,
#  106004883,
#  107348373,
#  106725784,
#  106128780,
#  107905435,
#  107664794,
#  108200352,
#  106725793,
#  106725797,
#  107905458,
#  108200391,
#  108429771,
#  107648418,
#  106758611,
#  108691938,
#  107971049,
#  107446767,
#  105939440,
#  108069365,
#  106037752,
#  105939455,
#  107151881,
#  106136075,
#  105972241,
#  105933572,
#  109773338,
#  107074993,
#  109773355,
#  106332253,
#  106496565,
#  105972279,
#  106496574,
#  107763125,
#  108233287,
#  107877816,
#  108069459,
#  106783845,
#  107184733,
#  108986979,
#  108003942,
#  107184744,
#  107184755,
#  108200564,
#  106179348,
#  108233342,
#  107840136,
#  108069522,
#  106463899,
#  106179355,
#  106169032,
#  106693341,
#  107195916,
#  106529510,
#  106169069,
#  107152116,
#  106446975,
#  107086593,
#  108790538,
#  107152155,
#  107152161,
#  106255836,
#  106693421,
#  106038070,
#  106038073,
#  107676475,
#  106857278,
#  106124768,
#  106955599,
#  107086677,
#  107664868,
#  106337538,
#  106813656,
#  106468627,
#  108139805,
#  108139811,
#  106927403,
#  108139820,
#  108139824,
#  108326451,
#  108139829,
#  106140984,
#  108139833,
#  108139837,
#  108139844,
#  108139849,
#  109286735,
#  108139857,
#  108139862,
#  106813668,
#  105977181,
#  106655291,
#  106468719,
#  105989011,
#  106403207,
#  109614474,
#  109375044,
#  106468770,
#  107648428,
#  108631471,
#  106567088,
#  106042808,
#  108041659,
#  ...]

# %%
predictions = bestModel.predictAll(candidate_climbs.map(lambda row: (0, row))).collect()
recommendations = sorted(predictions, key=lambda x: x[2], reverse=True)[:50]

# %%
print recommendations[:5]
# Out:
# [Rating(user=0, product=106263632, rating=15.805312998732049), Rating(user=0, product=105718552, rating=10.816297854584908), Rating(user=0, product=106645807, rating=10.744405817482319), Rating(user=0, product=108299472, rating=10.525427989990135), Rating(user=0, product=106036207, rating=9.86501447312777), Rating(user=0, product=107200940, rating=9.785426931692175), Rating(user=0, product=105851946, rating=9.355040872021704), Rating(user=0, product=106580214, rating=9.276725677744949), Rating(user=0, product=105836447, rating=9.085936109413808), Rating(user=0, product=107371476, rating=9.075664294142046), Rating(user=0, product=105832344, rating=9.069264099314662), Rating(user=0, product=106845038, rating=8.986805494465887), Rating(user=0, product=106674505, rating=8.863228097880597), Rating(user=0, product=105860937, rating=8.83486868685466), Rating(user=0, product=106187104, rating=8.805513730034821), Rating(user=0, product=106644498, rating=8.783813882001478), Rating(user=0, product=108265028, rating=8.760350685010163), Rating(user=0, product=106473854, rating=8.701773744151525), Rating(user=0, product=105850631, rating=8.521843646856482), Rating(user=0, product=106526228, rating=8.48827066565074), Rating(user=0, product=106024057, rating=8.369187255863391), Rating(user=0, product=106613481, rating=8.34489806244683), Rating(user=0, product=108326441, rating=8.2816378503193), Rating(user=0, product=106455468, rating=8.209709508347819), Rating(user=0, product=106853424, rating=7.992827527198219), Rating(user=0, product=105741758, rating=7.914522158585978), Rating(user=0, product=106053490, rating=7.897224266567327), Rating(user=0, product=106003624, rating=7.895420864848665), Rating(user=0, product=105741125, rating=7.840719308218757), Rating(user=0, product=105740417, rating=7.788509357802539), Rating(user=0, product=106596362, rating=7.784869045396003), Rating(user=0, product=105740420, rating=7.756178522727803), Rating(user=0, product=105718117, rating=7.7353185533567554), Rating(user=0, product=107258732, rating=7.681169251412915), Rating(user=0, product=106777929, rating=7.673010368576595), Rating(user=0, product=106868569, rating=7.649291435242395), Rating(user=0, product=106065685, rating=7.637595197032271), Rating(user=0, product=106056175, rating=7.624802732093775), Rating(user=0, product=105805175, rating=7.500786643899616), Rating(user=0, product=107727923, rating=7.43230009686749), Rating(user=0, product=106061772, rating=7.334061111026854), Rating(user=0, product=105741782, rating=7.303706394947293), Rating(user=0, product=106058057, rating=7.286705434670224), Rating(user=0, product=105997764, rating=7.286572048435214), Rating(user=0, product=107371011, rating=7.28444929815584), Rating(user=0, product=106704687, rating=7.244961484377532), Rating(user=0, product=106590696, rating=7.237255221946981), Rating(user=0, product=105837872, rating=7.188533613406387), Rating(user=0, product=106138026, rating=7.181916437560012), Rating(user=0, product=107142270, rating=7.177794451438037)]

